# %% [markdown]
# # Pandas
#
# Pandas is an open source library that provides easy-to-use data analysis tools for the Python programming language. In the second week of this course, you will learn how to manipulate and query data more effectively. We will cover topics such as Series and DataFrames, plotting, indexing, Groupby, stack and unstack, and some data visualizations. The data set we will be using are from Jesse's rowing and biking workouts. We will be using Python 3 version and the Anaconda distribution.
#
# Download the rowing and biking data in csv format from week 2 folder in Blackboard. Store them in the current working directory for access and use.
#
# In order for us to use pandas, we need to import Python's pandas library. Here we are importing the Python's pandas library with the **alias** pd. This means that if you want to access the functions and methods available, you only have to type pd and the function name.
#
#     import pandas as pd
#     pd.<method name>

# %%
import pandas as pd

# %% [markdown]
# # DataFrames
#
# A dataframe is like a two-dimensional area. You can think of a dataframe as being like a table or a spreadsheet with rows and columns. You can see from our rowing data set that the dataframe is made up of several columns such as time, distance, Pace, Watts, heart rate, etc. And each entry, or row, corresponds to the sample number.
#
# The first thing we'll need to do in our notebook, is to import pandas. Make sure your csv file is in the **working directory**
#
#     inport pandas as pd
#
#     rowing = pd.read_csv('../rowing.csv')
#     rowing.head()
#
# The function read_csv reads a comma-separated values (csv) file into DataFrame. Refer to the Jun-2 class recording (at ~36 min) for operational details.
#
# When specifying file names to the read_csv function, you can supply both absolute or relative file paths.
#
# A **relative path** is the path to the file if you start from your current working directory. In relative paths, typically the file will be in a subdirectory of the working directory and the path will not start with a drive specifier, e.g. (data/test_file.csv). The characters ‘..’ are used to move to a parent directory in a relative path.
#
# An **absolute path** is the complete path from the base of your file system to the file that you want to load, e.g. c:/Documents/data/test_file.csv. Absolute paths will start with a drive specifier (c:/ or d:/ in Windows, or ‘/’ in Mac or Linux)
#
# It’s recommended and preferred to use relative paths where possible in applications, because absolute paths are unlikely to work on different computers due to different directory structures.
#
# In order to view the dataframe, we enter the dataframes name which is rowing and run the following code.
#
#     rowing
#
# Jupiter notebook will display the first 5 rows and the last 5 rows. And we can see that in this dataframe, we have 1,435 rows.
#
# Read the biking csv file into a dataframe called biking in the cell below.

# %%
rowing = pd.read_csv('rowing.csv')
rowing.head()
rowing
# Out:
#       Number  Time (seconds)  Distance (meters)  Pace (seconds per 500m)  \
# 0          1             0.9                  3                    153.6
# 1          2             2.4                  8                    153.6
# 2          3             3.1                 11                    153.6
# 3          4             5.6                 20                    134.7
# 4          5             8.1                 30                    133.8
# ...      ...             ...                ...                      ...
# 1430    1431          3589.9              13732                    127.0
# 1431    1432          3592.3              13742                    126.7
# 1432    1433          3594.8              13752                    127.5
# 1433    1434          3597.2              13761                    128.0
# 1434    1435          3599.6              13771                    126.9
#
#       Watts  Cal/Hr  Stroke Rate  Heart Rate
# 0        97     632            0           0
# ...

# %% [markdown]
# # Series
#
# A Series is a one-dimensional array of indexed data. One of the huge benefits of Pandas is that it supports both integer and label-based indexing, and provides a host of methods for performing operations involving the index.
#
# The first column is known as an index. And, each of the other columns corresponds to a Series. The third Series is called Distance (meters), for keeping track of the distanced traveled. The 8th Series is called Heart Rate, and so on.
#
# Now, remember that each of the rows is also a Series, and this can be identified by this index number. So, how do you access the Series? Well, there are two ways of going about this. You can access them using a square bracket, using either a single quote or a double quote, notation. So, for example, you provide the dataframe name, and then the series name, in either single quotes, or double quotes, or you can use the dot notation. The square bracket notation for accessing a Series, will always work.
#
#     DataFrame['SeriesName'] or DataFrame["SeriesName"]
#
# The dot notation can be a shortcut, but it will not work if there's a space in the Series name. So, if you want to use the dot notation, you need to make certain that each of the column names does not have a space.
#
#     DataFrame.SeriesName
#
# Read two Series (Watts and Stroke Data) from the biking DataFrame in the cells below.

# %%
rowing['Stroke Rate']
# Out:
# 0        0
# 1        0
# 2        0
# 3       27
# 4       24
#         ..
# 1430    24
# 1431    24
# 1432    24
# 1433    25
# 1434    24
# Name: Stroke Rate, Length: 1435, dtype: int64

# %%
rowing['Watts']
# Out:
# 0        97
# 1        97
# 2        97
# 3       143
# 4       146
#        ...
# 1430    171
# 1431    172
# 1432    169
# 1433    167
# 1434    171
# Name: Watts, Length: 1435, dtype: int64

# %% [markdown]
# You can also access multiple series, and you can do that by including the series name in a list. Watch out the use of **double square brackets**.
#
# Read two combined Series (Time (seconds) and Watts) from the biking DataFrame in the cells below.

# %%
rowing[['Time (seconds)','Watts']]
# Out:
#       Time (seconds)  Watts
# 0                0.9     97
# 1                2.4     97
# 2                3.1     97
# 3                5.6    143
# 4                8.1    146
# ...              ...    ...
# 1430          3589.9    171
# 1431          3592.3    172
# 1432          3594.8    169
# 1433          3597.2    167
# 1434          3599.6    171
#
# [1435 rows x 2 columns]

# %% [markdown]
# In this question, you are not given a lot of directed instructions. We have covered approximately part of the topics in class. You are encouraged to look up information in the resources page in the week 2 folder to complete this problem. Ref: 10 minutes to pandas, pandas.pydata.org

# %% [markdown]
# ## Problem 1: Getting and Knowing Your Data

# %% [markdown]
# **Step 1. Import the necessary libraries** You will need both pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv)**

# %%
chip2 = pd.read_csv('Chipotle_Data.tsv', sep = '\t')
chip2.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# **Step 3. Assign it to a variable called chipo**

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipo = pd.read_csv(url, sep = '\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# **Step 4. See the first 10 entries**

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# **Step 5. What is the number of observations in the dataset?**

# %%
chipo
#4622 rows multiplied by 5 columns = 23,110 total observations
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# **Step 6. What is the number of columns in the dataset?**

# %%
## 5 columns
# Out:
# 23110

# %% [markdown]
# **Step 7. Print the name of all the columns.**

# %%
chipo.head(0)
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %% [markdown]
# **Step 8. How is the dataset indexed?**

# %%
#the data is indexed from 0 to 4621 and each index contains a list of each column
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# **Step 9. Which was the most-ordered item?**

# %%
chipo.item_name.mode()
chipo.item_name[4]
# Out:
# 'Chicken Bowl'

# %% [markdown]
# **Step 10. For the most-ordered item, how many items were ordered?**

# %%
counter = 0
for i in range(0,4622):
    if chipo.item_name[i] == 'Chicken Bowl':
        counter += 1
print(counter)
# Out:
# 726

# %% [markdown]
# ###### **Step 11. What was the most ordered item in the choice_description column?**

# %%
chipo.choice_description.mode()
# Out:
# 0    [Diet Coke]
# dtype: object

# %% [markdown]
# **Step 12. How many items were orderd in total?**

# %%
item_count = 0
for i in range(0,4622):
    if chipo.item_name[i] != 'NaN':
        item_count += 1
print(item_count)
# Out:
# 4622

# %% [markdown]
# **Step 13. Turn the item price into a float**

# %% [markdown]
# Step 13a. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# Step 13b. Create a lambda function and change the type of item price

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %% [markdown]
# Step 13c. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# **Step 14. How much was the revenue for the period in the dataset?**

# %%
revenue = 0
for i in range(0,4622):
    temp = chipo.item_price[i]
    revenue += temp
print('$',round(revenue,2))
# Out:
# $ 34500.16

# %% [markdown]
# **Step 15. How many orders were made in the period?**

# %%
order = 0
for i in range(0,4622):
    if i < 4621 and chipo.order_id[i] == chipo.order_id[i+1]:
        banana = 'yay'
    else:
        order = order + 1
print(order)
# Out:
# 1834

# %% [markdown]
# **Step 16. What is the average revenue amount per order?**

# %%
count = 0
a = np.zeros(1834)
for i in range(0,4622):
    if i < 4621 and chipo.order_id[i] == chipo.order_id[i+1]:
        a[count] = a[count]+chipo.item_price[i]             
    else:
        count = count + 1
print('$',round(np.average(a),2))
# Out:
# $ 12.68

# %% [markdown]
# **Step 17. How many different items are sold?**

# %%
b = []
num_item = 0
for i in range(0,4622):
    if chipo.item_name[i] not in b:
        num_item += 1
        b.append(chipo.item_name[i])
print(len(b),', There are repeated items however there is a difference between them (i.e. a hyphen)')
b
# Out:
# 50 , There are repeated items however there is a difference between them (i.e. a hyphen)
# ['Chips and Fresh Tomato Salsa',
#  'Izze',
#  'Nantucket Nectar',
#  'Chips and Tomatillo-Green Chili Salsa',
#  'Chicken Bowl',
#  'Side of Chips',
#  'Steak Burrito',
#  'Steak Soft Tacos',
#  'Chips and Guacamole',
#  'Chicken Crispy Tacos',
#  'Chicken Soft Tacos',
#  'Chicken Burrito',
#  'Canned Soda',
#  'Barbacoa Burrito',
#  'Carnitas Burrito',
#  'Carnitas Bowl',
#  'Bottled Water',
#  'Chips and Tomatillo Green Chili Salsa',
#  'Barbacoa Bowl',
#  'Chips',
#  'Chicken Salad Bowl',
#  'Steak Bowl',
#  'Barbacoa Soft Tacos',
#  'Veggie Burrito',
#  'Veggie Bowl',
#  'Steak Crispy Tacos',
#  'Chips and Tomatillo Red Chili Salsa',
#  'Barbacoa Crispy Tacos',
#  'Veggie Salad Bowl',
#  'Chips and Roasted Chili-Corn Salsa',
#  'Chips and Roasted Chili Corn Salsa',
#  'Carnitas Soft Tacos',
#  'Chicken Salad',
#  'Canned Soft Drink',
#  'Steak Salad Bowl',
#  '6 Pack Soft Drink',
# ...

# %% [markdown]
# ## Problem 2: Complex Upper-Limb Movements
# The Complex Upper-Limb Movements database contains hand trajectory data collected from subjects as they performed various upper-limb motor tasks. The data was used in the referenced work by Miranda et al. to identify motor primitives contributing to the observed motor patterns.
#
# ### Background
# The hand trajectory of motion during the performance of one-dimensional point-to-point movements has been shown to be marked by motor primitives with a bell-shaped velocity profile. Researchers have investigated if motor primitives with the same shape mark also complex upper-limb movements. They have done so by analyzing the magnitude of the hand trajectory velocity vector. This approach has failed to identify motor primitives with a bell-shaped velocity profile as the basic elements underlying the generation of complex upper-limb movements. In this study, we examined upper-limb movements by analyzing instead the movement components defined according to a Cartesian coordinate system with axes oriented in the medio-lateral, antero-posterior, and vertical directions.
#
# Ten healthy subjects (7 males; 26.4±4.52 years of age; 9 right-handed) with no known neurological or orthopedic conditions affecting the control of motion were recruited to participate in the study. Written informed consent was obtained from all subjects. The protocol was approved by the Institutional Review Board of Spaulding Rehabilitation Hospital. The dataset was collected in the Motion Analysis Lab (http://srh-mal.net/) at Spaulding Rehabilitation Hospital.
#
# ### Data Collection
# To explore the validity of the theoretical model proposed in the above-referenced manuscript, a group of ten healthy subjects were asked to perform a battery of upper-limb motor tasks. Data collected using a camera-based motion capture system (VICON, Oxford UK) was preprocessed using the system’s software to reconstruct the three-dimensional position of a reflective marker representing the hand trajectory of motion.
#
# ### Files
# The csv data files contain four columns. The data in the first column is the time axis in seconds. The data samples in the other three columns are the x-, y-, and z-coordinates of the reflective marker utilized in each experiment to represent the hand trajectory of movement. The data is reported in meters. Different files contain data pertaining to different subjects for different motor tasks. Different filenames are used for different tasks as follows:
#
#     BostonCA --> Writing the word Boston in Capital letters
#     BostonCU --> Writing the word Boston in cursive letters
#     HarvardCA --> Writing the word Harvard in Capital letters
#     HarvardCU --> Writing the word Harvard in cursive letters
#     Can --> 3D arm movements to reach for and transport a can of soda positioned on a table
#     Circle --> Drawing circles
#     Ellipse --> Drawing ellipses
#     Flower --> Drawing a pure frequency curve with v=4/3
#     Spiral --> Drawing a pure frequency curve with v=0
#     SuperMegaCloud --> Drawing a pure frequency curve with v=4/5
#     Triangle --> Drawing a pure frequency curve with v=3
#     Planned --> series of 2D planned (i.e. with target) movements of the arm
#     Unplanned --> series of 2D unplanned (i.e. without target) movements of the arm
#     Randomness --> 3D random movements
#
# ### Download
# [Link](https://physionet.org/static/published-projects/culm/complex-upper-limb-movements-1.0.0.zip)
#
# ### To Submit
# 1. Pick one of the subjects out of 10 (marked as S02 to S011)
# 2. Select any 2 hand movement trajectories. Load the data into pandas DataFrame.
# 3. Report 3 observations based on any data analysis of your guild's choice. You can compare/contrast different trajectories, compute reproducibility, identify any point of interest, and so on. You are highly recommended to plot the data for visualization purpose.
#
# Impress us with your creativity. We will discuss this problem on June-4.
#
# ### Reference
# Jose Garcia Vivas Miranda, Jean-François Daneault, Gloria Vergara-Diaz, Ângelo Frederico Souza de Oliveira e Torres, Ana Paula Quixadá, Marcus de Lemos Fonseca, João Paulo Bomfim Cruz Vieira, Vitor Sotero dos Santos, Thiago Cruz da Figueiredo, Elen Beatriz Pinto, Norberto Peña & Paolo Bonato (2018). Complex Upper-Limb Movements Are Generated by Combining Motor Primitives that Scale with the Movement Size. Scientific Reports. 8(1). DOI:10.1038/s41598-018-29470-y.
#
# Goldberger, A., Amaral, L., Glass, L., Hausdorff, J., Ivanov, P. C., Mark, R., ... & Stanley, H. E. (2000). PhysioBank, PhysioToolkit, and PhysioNet: Components of a new research resource for complex physiologic signals. Circulation [Online]. 101 (23), pp. e215–e220.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# print the graphs in the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")

# %%
flower = pd.read_csv('Flower01_copy.csv',sep=';')
flower.tail()
# Out:
#            t        X        Y        Z
# 2087  17.400 -0.88264  0.19085  0.78698
# 2088  17.408 -0.88302  0.19098  0.78825
# 2089  17.417 -0.88342  0.19098  0.78927
# 2090  17.425 -0.88386  0.19104  0.79043
# 2091  17.433 -0.88436  0.19139  0.79125

# %%
x_axis = sns.distplot(flower.X)
y_axis = sns.distplot(flower.Y)
#z_axis = sns.distplot(flower.Z)

# %%
sns.jointplot(x = "X",y = "Y", data = flower)

# %%
sns.pairplot(flower)

# %%
cloud = pd.read_csv('SuperMegaCloud01.csv', sep = ';')
cloud.head()
# Out:
#           t        X        Y        Z
# 0  0.008333 -0.89041  0.20551  0.78074
# 1  0.016667 -0.89039  0.20550  0.78074
# 2  0.025000 -0.89039  0.20548  0.78075
# 3  0.033333 -0.89037  0.20548  0.78076
# 4  0.041667 -0.89036  0.20548  0.78080

# %%
sns.pairplot(cloud)

# %%
spiral = pd.read_csv('Spiral01.csv', sep = ';')
sns.pairplot(spiral)

# %%
spiral.head()
# Out:
#           t        X        Y        Z
# 0  0.008333 -0.89733  0.22065  0.78029
# 1  0.016667 -0.89739  0.22067  0.78030
# 2  0.025000 -0.89751  0.22041  0.78037
# 3  0.033333 -0.89740  0.22066  0.78034
# 4  0.041667 -0.89750  0.22045  0.78041

# %%
sns.jointplot(x = "X",y = "Y", data = spiral)

# %%
sns.jointplot(x = "X",y = "Y", data = cloud)

# %%
cloud2 = pd.read_csv('SuperMegaCloud03.csv', sep = ';')
sns.jointplot(x = "X",y = "Y", data = cloud2)
sns.jointplot(x = "X",y = "Y", data = cloud)

# %%
C1stdX = cloud.X.std()
C1stdY = cloud.Y.std()
print('X and Y Standard deviation of cloud 1 respectively:', round(C1stdX,5),',',round(C1stdY,5))
C2stdX = cloud2.X.std()
C2stdY = cloud2.Y.std()
print('X and Y Standard deviation of cloud 2 respectively:',round(C2stdX,5),',',round(C2stdY,5))
# Out:
# X and Y Standard deviation of cloud 1 respectively: 0.01129 , 0.01195
# X and Y Standard deviation of cloud 2 respectively: 0.04325 , 0.04567

# %%
cloud = cloud.iloc[0:2536]
cloud.tail()
# Out:
#            t        X        Y        Z
# 2531  21.100 -0.88730  0.22274  0.79746
# 2532  21.108 -0.88752  0.22342  0.80013
# 2533  21.117 -0.88810  0.22421  0.80290
# 2534  21.125 -0.88836  0.22504  0.80566
# 2535  21.133 -0.88881  0.22600  0.80863

# %%
rangeC1 = [max(cloud.X)-min(cloud.X),max(cloud.Y)-min(cloud.Y)]
print(rangeC1)
rangeC2 = [max(cloud2.X)-min(cloud2.X),max(cloud2.Y)-min(cloud2.Y)]
print(rangeC2)
# Out:
# [0.04059999999999997, 0.039360000000000034]
# [0.14905999999999997, 0.15380000000000005]

# %% [markdown]
# # Observation 1:
# The data for SuperMegaCloud01 continues tracking the reflective surface after the subject
# is finished drawing, this is evident as outlying data points outside of the desired cloud
# and reinforced by the time and x, time and y, and time and z graphs where a quick movement
# over a short period of time is observed. This is a point of interest in the data
#
# # Observation 2:
# The x and y data points when plot against time show a very similar pattern for the data
# for flower, spiral and cloud. This is showing the spatial relationship between the
# circular motion of all three shapes the subject is drawing
#
# # Observation 3:
# The data's reproducability across the same task is difficult to asses due to the change
# in size and location of the drawing within the monitered 3D space. This is evident when
# comparing the data from SuperMegaCloud01 and SuperMegaCloud03, specifically when looking
# at the x and y standard deviations. This could also serve to illustrate the learning that
# is taking place by the subject. For example the range of x and y data in cloud2 is much as 5 times greater for y and approximately 3.5 times greater for x in cloud1 (when the outlying data is ignored and when it is assumed that SuperMegaCloud01 took place before SuperMegaCloud03)
